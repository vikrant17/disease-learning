# %%
import pandas as pd
import numpy as np
import re
import os
import glob

# %%
dataset = pd.read_csv('./disease-symptom-db.csv', encoding='utf-8', index_col=None, header=0)

# %%
dataset
# Out:
#                                     Disease_UMLS Disease_CUI  \
# 0             porphyrie , akute intermittierende    C0162565
# 1             porphyrie , akute intermittierende    C0162565
# 2             porphyrie , akute intermittierende    C0162565
# 3             porphyrie , akute intermittierende    C0162565
# 4             porphyrie , akute intermittierende    C0162565
# 5             porphyrie , akute intermittierende    C0162565
# 6                        porphyria cutanea tarda    C0162566
# 7                        porphyria cutanea tarda    C0162566
# 8                                 vorhofflimmern    C0004238
# 9                                 vorhofflimmern    C0004238
# 10                                vorhofflimmern    C0004238
# 11                                vorhofflimmern    C0004238
# 12                                vorhofflimmern    C0004238
# 13                                vorhofflimmern    C0004238
# ...

# %%
dataset = dataset[:150]

# %%
dataset
# Out:
#                            Disease_UMLS Disease_CUI  \
# 0    porphyrie , akute intermittierende    C0162565
# 1    porphyrie , akute intermittierende    C0162565
# 2    porphyrie , akute intermittierende    C0162565
# 3    porphyrie , akute intermittierende    C0162565
# 4    porphyrie , akute intermittierende    C0162565
# 5    porphyrie , akute intermittierende    C0162565
# 6               porphyria cutanea tarda    C0162566
# 7               porphyria cutanea tarda    C0162566
# 8                        vorhofflimmern    C0004238
# 9                        vorhofflimmern    C0004238
# 10                       vorhofflimmern    C0004238
# 11                       vorhofflimmern    C0004238
# 12                       vorhofflimmern    C0004238
# 13                       vorhofflimmern    C0004238
# 14                       vorhofflimmern    C0004238
# 15                       vorhofflimmern    C0004238
# 16                       vorhofflimmern    C0004238
# ...

# %%
df_dataset = pd.DataFrame(dataset)

# %%
df_dataset
# Out:
#                            Disease_UMLS Disease_CUI  \
# 0    porphyrie , akute intermittierende    C0162565
# 1    porphyrie , akute intermittierende    C0162565
# 2    porphyrie , akute intermittierende    C0162565
# 3    porphyrie , akute intermittierende    C0162565
# 4    porphyrie , akute intermittierende    C0162565
# 5    porphyrie , akute intermittierende    C0162565
# 6               porphyria cutanea tarda    C0162566
# 7               porphyria cutanea tarda    C0162566
# 8                        vorhofflimmern    C0004238
# 9                        vorhofflimmern    C0004238
# 10                       vorhofflimmern    C0004238
# 11                       vorhofflimmern    C0004238
# 12                       vorhofflimmern    C0004238
# 13                       vorhofflimmern    C0004238
# 14                       vorhofflimmern    C0004238
# 15                       vorhofflimmern    C0004238
# 16                       vorhofflimmern    C0004238
# ...

# %%
df_dataset = df_dataset.drop_duplicates(subset=['Disease_CUI', 'Symptom_CUI'])

# %%
df_dataset
# Out:
#                            Disease_UMLS Disease_CUI  \
# 0    porphyrie , akute intermittierende    C0162565
# 1    porphyrie , akute intermittierende    C0162565
# 2    porphyrie , akute intermittierende    C0162565
# 3    porphyrie , akute intermittierende    C0162565
# 4    porphyrie , akute intermittierende    C0162565
# 5    porphyrie , akute intermittierende    C0162565
# 6               porphyria cutanea tarda    C0162566
# 7               porphyria cutanea tarda    C0162566
# 8                        vorhofflimmern    C0004238
# 9                        vorhofflimmern    C0004238
# 10                       vorhofflimmern    C0004238
# 11                       vorhofflimmern    C0004238
# 12                       vorhofflimmern    C0004238
# 13                       vorhofflimmern    C0004238
# 14                       vorhofflimmern    C0004238
# 16                       vorhofflimmern    C0004238
# 19                       vorhofflimmern    C0004238
# ...

# %%
df_dataset.to_csv("./disease-symptom-cleaned.csv",index=False)

# %%
disease_symptom_condensed = df_dataset[['Disease_CUI', 'Symptom_CUI']]

# %%
disease_symptom_condensed
# Out:
#     Disease_CUI Symptom_CUI
# 0      C0162565    C0039239
# 1      C0162565    C0000737
# 2      C0162565    C0235704
# 3      C0162565    C0030554
# 4      C0162565    C0030552
# 5      C0162565    C0020538
# 6      C0162566    C0020555
# 7      C0162566    C0005758
# 8      C0004238    C0030252
# 9      C0004238    C1868917
# 10     C0004238    C0392684
# 11     C0004238    C0012833
# 12     C0004238    C0003467
# 13     C0004238    C0857217
# 14     C0004238    C0013404
# 16     C0004238    C0032617
# 19     C0004238    C0039070
# 20     C0023212    C0013404
# 21     C0023212    C0231807
# 22     C0023212    C0085619
# 23     C0023212    C0231835
# 24     C0023212    C0231912
# 25     C0023212    C1956414
# 26     C0023212    C0010520
# 27     C0023212    C0034063
# 28     C0023212    C0032227
# 30     C0023212    C1695782
# 31     C0023212    C0920048
# 32     C0023212    C0009676
# 33     C0023212    C3714552
# ..          ...         ...
# 120    C0947845    C0015967
# ...

# %%
disease_symptom_condensed.columns = ['Disease', 'Symptom']

# %%
disease_symptom_condensed
# Out:
#       Disease   Symptom
# 0    C0162565  C0039239
# 1    C0162565  C0000737
# 2    C0162565  C0235704
# 3    C0162565  C0030554
# 4    C0162565  C0030552
# 5    C0162565  C0020538
# 6    C0162566  C0020555
# 7    C0162566  C0005758
# 8    C0004238  C0030252
# 9    C0004238  C1868917
# 10   C0004238  C0392684
# 11   C0004238  C0012833
# 12   C0004238  C0003467
# 13   C0004238  C0857217
# 14   C0004238  C0013404
# 16   C0004238  C0032617
# 19   C0004238  C0039070
# 20   C0023212  C0013404
# 21   C0023212  C0231807
# 22   C0023212  C0085619
# 23   C0023212  C0231835
# 24   C0023212  C0231912
# 25   C0023212  C1956414
# 26   C0023212  C0010520
# 27   C0023212  C0034063
# 28   C0023212  C0032227
# 30   C0023212  C1695782
# 31   C0023212  C0920048
# 32   C0023212  C0009676
# 33   C0023212  C3714552
# ..        ...       ...
# 120  C0947845  C0015967
# 121  C0947845  C0015672
# 122  C0947845  C0003123
# 123  C0947845  C2363736
# 124  C0947845  C0013404
# 125  C0947845  C0010200
# ...

# %%
disease_symptom_condensed.to_csv('./disease_symptom_condensed.csv', index=False)
